# %%
import glob
import os 
import string
from pathlib import Path

from PIL import Image
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from torchvision.models import resnet18
import matplotlib.pyplot as plt
import collections

from IPython.display import clear_output
# %matplotlib inline
plt.style.use('seaborn')

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/customocrdata/models/crnn.pt
# /kaggle/input/customocrdata/data/val/e84n2.png
# /kaggle/input/customocrdata/data/val/n8ydd.png
# /kaggle/input/customocrdata/data/val/bgd4m.png
# /kaggle/input/customocrdata/data/val/g842c.png
# /kaggle/input/customocrdata/data/val/c4527.png
# /kaggle/input/customocrdata/data/val/mmy5n.png
# /kaggle/input/customocrdata/data/val/2fxgd.png
# /kaggle/input/customocrdata/data/val/2w4y7.png
# /kaggle/input/customocrdata/data/val/nmy2x.png
# /kaggle/input/customocrdata/data/val/p8c24.png
# /kaggle/input/customocrdata/data/val/2enf4.png
# /kaggle/input/customocrdata/data/val/785n4.png
# /kaggle/input/customocrdata/data/val/b55d6.png
# /kaggle/input/customocrdata/data/val/nxx25.png
# /kaggle/input/customocrdata/data/val/5yxgp.png
# /kaggle/input/customocrdata/data/val/5nm6d.png
# /kaggle/input/customocrdata/data/val/dbfen.png
# /kaggle/input/customocrdata/data/val/7d44m.png
# /kaggle/input/customocrdata/data/val/e4gd7.png
# /kaggle/input/customocrdata/data/val/wdww8.png
# /kaggle/input/customocrdata/data/val/7w67m.png
# /kaggle/input/customocrdata/data/val/gy5bf.png
# /kaggle/input/customocrdata/data/val/78dw6.jpg
# /kaggle/input/customocrdata/data/val/4ynf3.png
# /kaggle/input/customocrdata/data/val/edg3p.png
# /kaggle/input/customocrdata/data/val/f4fn2.png
# /kaggle/input/customocrdata/data/val/2yggg.png
# /kaggle/input/customocrdata/data/val/d4ppy.png
# /kaggle/input/customocrdata/data/val/d6fcn.png
# /kaggle/input/customocrdata/data/val/3ym7f.png
# /kaggle/input/customocrdata/data/val/p8ngx.png
# /kaggle/input/customocrdata/data/val/bdbb3.png
# /kaggle/input/customocrdata/data/val/geyn5.jpg
# /kaggle/input/customocrdata/data/val/mwdf6.png
# /kaggle/input/customocrdata/data/val/2g7nm.png
# /kaggle/input/customocrdata/data/val/pf5ng.png
# /kaggle/input/customocrdata/data/val/74853.png
# /kaggle/input/customocrdata/data/val/ndyfe.png
# /kaggle/input/customocrdata/data/val/wbncw.png
# /kaggle/input/customocrdata/data/val/d4n82.png
# /kaggle/input/customocrdata/data/val/3ye2e.png
# /kaggle/input/customocrdata/data/val/fw3b2.png
# /kaggle/input/customocrdata/data/val/5nnff.png
# /kaggle/input/customocrdata/data/val/w6pxy.png
# /kaggle/input/customocrdata/data/val/ycnfc.png
# /kaggle/input/customocrdata/data/val/x76mn.png
# /kaggle/input/customocrdata/data/val/g247w.png
# /kaggle/input/customocrdata/data/val/bny23.png
# /kaggle/input/customocrdata/data/val/f858x.png
# /kaggle/input/customocrdata/data/val/268g2.png
# /kaggle/input/customocrdata/data/val/2wc38.png
# /kaggle/input/customocrdata/data/val/bgxcd.jpg
# /kaggle/input/customocrdata/data/val/c6745.png
# /kaggle/input/customocrdata/data/val/8d2nd.png
# /kaggle/input/customocrdata/data/val/5ng6e.png
# /kaggle/input/customocrdata/data/val/fg38b.png
# /kaggle/input/customocrdata/data/val/n3ffn.png
# /kaggle/input/customocrdata/data/val/6c3n6.png
# /kaggle/input/customocrdata/data/val/8ne4g.png
# /kaggle/input/customocrdata/data/val/44ype.png
# /kaggle/input/customocrdata/data/val/bgb48.png
# /kaggle/input/customocrdata/data/val/nn6w6.jpg
# /kaggle/input/customocrdata/data/val/6b4w6.png
# /kaggle/input/customocrdata/data/val/5mgn4.png
# /kaggle/input/customocrdata/data/val/f5cm2.png
# /kaggle/input/customocrdata/data/val/4n3mn.png
# /kaggle/input/customocrdata/data/val/5npdn.png
# /kaggle/input/customocrdata/data/val/pdcp4.png
# /kaggle/input/customocrdata/data/val/8eggg.png
# /kaggle/input/customocrdata/data/val/xxbm5.png
# /kaggle/input/customocrdata/data/val/fp762.png
# /kaggle/input/customocrdata/data/val/gewfy.png
# /kaggle/input/customocrdata/data/val/m457d.png
# /kaggle/input/customocrdata/data/val/mpxfb.png
# /kaggle/input/customocrdata/data/val/3ygde.png
# /kaggle/input/customocrdata/data/val/c6we6.png
# /kaggle/input/customocrdata/data/val/7bwm2.png
# /kaggle/input/customocrdata/data/val/cdcb3.png
# /kaggle/input/customocrdata/data/val/c55c6.png
# /kaggle/input/customocrdata/data/val/n5wbg.png
# /kaggle/input/customocrdata/data/val/n2by7.png
# /kaggle/input/customocrdata/data/val/32cnn.png
# /kaggle/input/customocrdata/data/val/d2nbn.png
# /kaggle/input/customocrdata/data/val/8xef7.png
# /kaggle/input/customocrdata/data/val/3n7mx.png
# /kaggle/input/customocrdata/data/val/c482b.png
# /kaggle/input/customocrdata/data/val/c2g4d.png
# /kaggle/input/customocrdata/data/val/gfxcc.png
# /kaggle/input/customocrdata/data/val/dpbyd.png
# /kaggle/input/customocrdata/data/val/58pnp.png
# /kaggle/input/customocrdata/data/val/73mnx.png
# /kaggle/input/customocrdata/data/val/n8fp6.png
# /kaggle/input/customocrdata/data/val/5n732.png
# /kaggle/input/customocrdata/data/val/pp87n.png
# /kaggle/input/customocrdata/data/val/4fc36.png
# /kaggle/input/customocrdata/data/val/6dmx7.png
# /kaggle/input/customocrdata/data/val/bpwd7.png
# /kaggle/input/customocrdata/data/val/ebcbx.png
# /kaggle/input/customocrdata/data/val/76y6f.png
# /kaggle/input/customocrdata/data/val/f753f.png
# /kaggle/input/customocrdata/data/val/wg625.png
# /kaggle/input/customocrdata/data/val/5xwcg.png
# /kaggle/input/customocrdata/data/val/6xpme.png
# /kaggle/input/customocrdata/data/val/6e2dg.png
# /kaggle/input/customocrdata/data/val/m6n4x.png
# /kaggle/input/customocrdata/data/val/ne325.png
# /kaggle/input/customocrdata/data/val/nfndw.png
# /kaggle/input/customocrdata/data/val/n6xc5.png
# /kaggle/input/customocrdata/data/val/gpnxn.png
# /kaggle/input/customocrdata/data/val/4d22m.png
# /kaggle/input/customocrdata/data/val/nb45d.png
# /kaggle/input/customocrdata/data/val/cwmny.png
# /kaggle/input/customocrdata/data/val/yemy4.png
# /kaggle/input/customocrdata/data/val/yg5bb.png
# /kaggle/input/customocrdata/data/val/myc3c.png
# /kaggle/input/customocrdata/data/val/8684m.png
# /kaggle/input/customocrdata/data/val/y32yy.png
# /kaggle/input/customocrdata/data/val/m74dm.png
# /kaggle/input/customocrdata/data/val/mcyfx.png
# /kaggle/input/customocrdata/data/val/yw667.png
# /kaggle/input/customocrdata/data/val/c5xne.png
# /kaggle/input/customocrdata/data/val/67dey.png
# /kaggle/input/customocrdata/data/val/bw44w.png
# /kaggle/input/customocrdata/data/val/x7547.png
# /kaggle/input/customocrdata/data/val/w2e87.png
# /kaggle/input/customocrdata/data/val/nf8b8.png
# /kaggle/input/customocrdata/data/val/nn4wx.png
# /kaggle/input/customocrdata/data/val/xdn65.png
# /kaggle/input/customocrdata/data/val/ycmcw.png
# /kaggle/input/customocrdata/data/val/x362g.png
# /kaggle/input/customocrdata/data/val/5p8fm.png
# /kaggle/input/customocrdata/data/val/m3wfw.png
# /kaggle/input/customocrdata/data/val/mmg2m.png
# /kaggle/input/customocrdata/data/val/6b46g.png
# /kaggle/input/customocrdata/data/val/77wp4.png
# /kaggle/input/customocrdata/data/val/2gyb6.png
# /kaggle/input/customocrdata/data/val/c4bgd.png
# /kaggle/input/customocrdata/data/val/pp546.png
# /kaggle/input/customocrdata/data/val/xfgxb.png
# /kaggle/input/customocrdata/data/val/6pfy4.png
# /kaggle/input/customocrdata/data/val/pgm2e.png
# /kaggle/input/customocrdata/data/val/wfy5m.png
# /kaggle/input/customocrdata/data/val/g3dy6.png
# /kaggle/input/customocrdata/data/val/6wg4n.png
# /kaggle/input/customocrdata/data/val/p7fyp.png
# /kaggle/input/customocrdata/data/val/23n88.png
# /kaggle/input/customocrdata/data/val/gp22x.png
# /kaggle/input/customocrdata/data/val/3eny7.png
# /kaggle/input/customocrdata/data/val/nbwpn.png
# /kaggle/input/customocrdata/data/val/n4cpy.png
# /kaggle/input/customocrdata/data/val/77n6g.png
# /kaggle/input/customocrdata/data/val/nb267.png
# /kaggle/input/customocrdata/data/val/gfbx6.png
# /kaggle/input/customocrdata/data/val/mcg43.png
# /kaggle/input/customocrdata/data/val/xe8xm.png
# /kaggle/input/customocrdata/data/val/dyp7n.png
# /kaggle/input/customocrdata/data/val/6n443.png
# /kaggle/input/customocrdata/data/val/dcnp8.png
# /kaggle/input/customocrdata/data/val/x44n4.png
# /kaggle/input/customocrdata/data/val/8n34n.png
# /kaggle/input/customocrdata/data/val/5nxnn.png
# /kaggle/input/customocrdata/data/val/44fyb.png
# /kaggle/input/customocrdata/data/val/7dgc2.png
# /kaggle/input/customocrdata/data/val/gfp54.png
# /kaggle/input/customocrdata/data/val/5bnd7.png
# /kaggle/input/customocrdata/data/val/6bdn5.png
# /kaggle/input/customocrdata/data/val/pg4bf.png
# /kaggle/input/customocrdata/data/val/52447.png
# /kaggle/input/customocrdata/data/val/f6bpw.jpg
# /kaggle/input/customocrdata/data/val/m22e3.png
# /kaggle/input/customocrdata/data/val/nbp3e.png
# /kaggle/input/customocrdata/data/val/yd755.png
# /kaggle/input/customocrdata/data/val/6m5eg.png
# /kaggle/input/customocrdata/data/val/f4wfn.png
# /kaggle/input/customocrdata/data/val/cwdnx.png
# /kaggle/input/customocrdata/data/val/d7c5x.png
# /kaggle/input/customocrdata/data/val/46mbm.png
# /kaggle/input/customocrdata/data/val/mfc35.png
# /kaggle/input/customocrdata/data/val/px8n8.png
# /kaggle/input/customocrdata/data/val/nn6mg.png
# /kaggle/input/customocrdata/data/val/gy8xb.png
# /kaggle/input/customocrdata/data/val/cx3wg.png
# /kaggle/input/customocrdata/data/val/ef4mn.png
# /kaggle/input/customocrdata/data/val/nnn5p.png
# /kaggle/input/customocrdata/data/val/bn5mw.png
# /kaggle/input/customocrdata/data/val/pn7pn.png
# /kaggle/input/customocrdata/data/val/cdfen.png
# /kaggle/input/customocrdata/data/val/7fmcy.png
# /kaggle/input/customocrdata/data/val/8npd5.png
# /kaggle/input/customocrdata/data/val/efg72.png
# /kaggle/input/customocrdata/data/val/ybfx6.png
# /kaggle/input/customocrdata/data/val/xymfn.png
# /kaggle/input/customocrdata/data/val/xe6eb.png
# /kaggle/input/customocrdata/data/val/de45x.png
# /kaggle/input/customocrdata/data/val/25w53.png
# /kaggle/input/customocrdata/data/val/63824.png
# /kaggle/input/customocrdata/data/val/xnd3y.png
# /kaggle/input/customocrdata/data/val/f228n.png
# /kaggle/input/customocrdata/data/val/w4cdc.png
# /kaggle/input/customocrdata/data/val/ggd7m.png
# /kaggle/input/customocrdata/data/val/efx34.png
# /kaggle/input/customocrdata/data/val/gd8fb.png
# /kaggle/input/customocrdata/data/val/n2gmg.png
# /kaggle/input/customocrdata/data/val/pw5nc.png
# /kaggle/input/customocrdata/data/val/n5n8b.png
# /kaggle/input/customocrdata/data/val/xf5g7.png
# /kaggle/input/customocrdata/data/val/7y2x4.png
# /kaggle/input/customocrdata/data/val/n3xfg.jpg
# /kaggle/input/customocrdata/data/val/y48c3.png
# /kaggle/input/customocrdata/data/val/77387.png
# /kaggle/input/customocrdata/data/val/pxdwp.png
# /kaggle/input/customocrdata/data/val/n3m6x.png
# /kaggle/input/customocrdata/data/val/g888x.png
# /kaggle/input/customocrdata/data/val/n7enn.png
# /kaggle/input/customocrdata/data/train/bmxpe.png
# /kaggle/input/customocrdata/data/train/8n65n.png
# /kaggle/input/customocrdata/data/train/ecd4w.png
# /kaggle/input/customocrdata/data/train/574d7.png
# /kaggle/input/customocrdata/data/train/x3fwf.png
# /kaggle/input/customocrdata/data/train/87nym.png
# /kaggle/input/customocrdata/data/train/2cgyx.png
# /kaggle/input/customocrdata/data/train/64b3p.png
# /kaggle/input/customocrdata/data/train/be3bp.png
# /kaggle/input/customocrdata/data/train/c8fxy.png
# /kaggle/input/customocrdata/data/train/men4f.png
# /kaggle/input/customocrdata/data/train/87d4c.png
# /kaggle/input/customocrdata/data/train/dbny3.png
# /kaggle/input/customocrdata/data/train/gp7c5.png
# /kaggle/input/customocrdata/data/train/b5pnn.png
# /kaggle/input/customocrdata/data/train/y4ec2.png
# /kaggle/input/customocrdata/data/train/wnpec.png
# /kaggle/input/customocrdata/data/train/6n5fd.png
# /kaggle/input/customocrdata/data/train/nnn57.png
# /kaggle/input/customocrdata/data/train/6mygb.png
# /kaggle/input/customocrdata/data/train/cdmn8.png
# /kaggle/input/customocrdata/data/train/5expp.png
# /kaggle/input/customocrdata/data/train/pwebm.png
# /kaggle/input/customocrdata/data/train/7wn74.png
# /kaggle/input/customocrdata/data/train/47m2b.png
# /kaggle/input/customocrdata/data/train/y7x8p.png
# /kaggle/input/customocrdata/data/train/gegw4.png
# /kaggle/input/customocrdata/data/train/gwnm6.png
# /kaggle/input/customocrdata/data/train/85dxn.png
# /kaggle/input/customocrdata/data/train/x6b5m.png
# /kaggle/input/customocrdata/data/train/ee8fg.png
# /kaggle/input/customocrdata/data/train/p24gn.png
# /kaggle/input/customocrdata/data/train/5325m.png
# /kaggle/input/customocrdata/data/train/25m6p.png
# /kaggle/input/customocrdata/data/train/p4pde.png
# /kaggle/input/customocrdata/data/train/3den6.png
# /kaggle/input/customocrdata/data/train/53mn8.png
# /kaggle/input/customocrdata/data/train/mp7wp.png
# /kaggle/input/customocrdata/data/train/664nf.png
# /kaggle/input/customocrdata/data/train/3p67n.png
# /kaggle/input/customocrdata/data/train/646x8.png
# /kaggle/input/customocrdata/data/train/nngxc.png
# /kaggle/input/customocrdata/data/train/fdpgd.png
# /kaggle/input/customocrdata/data/train/88bgx.png
# /kaggle/input/customocrdata/data/train/xc68n.png
# /kaggle/input/customocrdata/data/train/m8m4x.png
# /kaggle/input/customocrdata/data/train/gnbn4.png
# /kaggle/input/customocrdata/data/train/fy2nd.png
# /kaggle/input/customocrdata/data/train/ywn6f.png
# /kaggle/input/customocrdata/data/train/yf28d.png
# /kaggle/input/customocrdata/data/train/664dn.png
# /kaggle/input/customocrdata/data/train/wm47f.png
# /kaggle/input/customocrdata/data/train/7yf62.png
# /kaggle/input/customocrdata/data/train/33f7m.png
# /kaggle/input/customocrdata/data/train/g8gnd.png
# /kaggle/input/customocrdata/data/train/8n2pg.png
# /kaggle/input/customocrdata/data/train/658xe.png
# /kaggle/input/customocrdata/data/train/yf347.png
# /kaggle/input/customocrdata/data/train/7m8px.png
# /kaggle/input/customocrdata/data/train/fc6xb.png
# /kaggle/input/customocrdata/data/train/bnc2f.png
# /kaggle/input/customocrdata/data/train/f85y3.png
# /kaggle/input/customocrdata/data/train/cb8cf.png
# /kaggle/input/customocrdata/data/train/2mg87.png
# /kaggle/input/customocrdata/data/train/pg2pm.png
# /kaggle/input/customocrdata/data/train/b5nmm.png
# /kaggle/input/customocrdata/data/train/7fde7.png
# /kaggle/input/customocrdata/data/train/bw6n6.png
# /kaggle/input/customocrdata/data/train/7e2y7.png
# /kaggle/input/customocrdata/data/train/pbpgc.png
# /kaggle/input/customocrdata/data/train/8np22.png
# /kaggle/input/customocrdata/data/train/gn2d3.png
# /kaggle/input/customocrdata/data/train/f35xp.png
# /kaggle/input/customocrdata/data/train/wm746.png
# /kaggle/input/customocrdata/data/train/e7nx4.png
# /kaggle/input/customocrdata/data/train/mdyp7.png
# /kaggle/input/customocrdata/data/train/cfw6e.png
# /kaggle/input/customocrdata/data/train/85622.png
# /kaggle/input/customocrdata/data/train/yge7c.jpg
# /kaggle/input/customocrdata/data/train/mb4en.png
# /kaggle/input/customocrdata/data/train/fcmem.png
# /kaggle/input/customocrdata/data/train/fwxdp.png
# /kaggle/input/customocrdata/data/train/xdcn4.png
# /kaggle/input/customocrdata/data/train/8w875.png
# /kaggle/input/customocrdata/data/train/6ecbn.png
# /kaggle/input/customocrdata/data/train/x2cnn.png
# /kaggle/input/customocrdata/data/train/2cg58.png
# /kaggle/input/customocrdata/data/train/dd5w5.png
# /kaggle/input/customocrdata/data/train/74eyg.png
# /kaggle/input/customocrdata/data/train/wc2bd.png
# /kaggle/input/customocrdata/data/train/ppwyd.png
# /kaggle/input/customocrdata/data/train/g6n7x.png
# /kaggle/input/customocrdata/data/train/mxyxw.png
# /kaggle/input/customocrdata/data/train/f5e5e.png
# /kaggle/input/customocrdata/data/train/6gnm3.png
# /kaggle/input/customocrdata/data/train/x4gg5.png
# /kaggle/input/customocrdata/data/train/g2fnw.png
# /kaggle/input/customocrdata/data/train/wce5n.png
# /kaggle/input/customocrdata/data/train/befbd.png
# /kaggle/input/customocrdata/data/train/n7ebx.png
# /kaggle/input/customocrdata/data/train/bp2d4.png
# /kaggle/input/customocrdata/data/train/c2fb7.png
# /kaggle/input/customocrdata/data/train/nxn4f.png
# /kaggle/input/customocrdata/data/train/865wm.png
# /kaggle/input/customocrdata/data/train/4egem.png
# /kaggle/input/customocrdata/data/train/x74b2.png
# /kaggle/input/customocrdata/data/train/2bg48.png
# /kaggle/input/customocrdata/data/train/cffp4.png
# /kaggle/input/customocrdata/data/train/2g783.png
# /kaggle/input/customocrdata/data/train/ny3nn.png
# /kaggle/input/customocrdata/data/train/x458w.png
# /kaggle/input/customocrdata/data/train/7mgmf.png
# /kaggle/input/customocrdata/data/train/ddxpp.jpg
# /kaggle/input/customocrdata/data/train/xyncc.png
# /kaggle/input/customocrdata/data/train/5pm6b.png
# /kaggle/input/customocrdata/data/train/bc8nf.png
# /kaggle/input/customocrdata/data/train/5mfff.png
# /kaggle/input/customocrdata/data/train/pcede.png
# /kaggle/input/customocrdata/data/train/de7f8.png
# /kaggle/input/customocrdata/data/train/dw6mn.png
# /kaggle/input/customocrdata/data/train/c7nn8.png
# /kaggle/input/customocrdata/data/train/e76n4.png
# /kaggle/input/customocrdata/data/train/43p5d.png
# /kaggle/input/customocrdata/data/train/37d52.png
# /kaggle/input/customocrdata/data/train/gn2xy.png
# /kaggle/input/customocrdata/data/train/n6nn2.png
# /kaggle/input/customocrdata/data/train/en32e.png
# /kaggle/input/customocrdata/data/train/e46yw.png
# /kaggle/input/customocrdata/data/train/bm3p8.png
# /kaggle/input/customocrdata/data/train/25257.png
# /kaggle/input/customocrdata/data/train/pym7p.png
# /kaggle/input/customocrdata/data/train/dmx8p.png
# /kaggle/input/customocrdata/data/train/y2436.png
# /kaggle/input/customocrdata/data/train/pwn5e.png
# /kaggle/input/customocrdata/data/train/efgx5.png
# /kaggle/input/customocrdata/data/train/36nx4.png
# /kaggle/input/customocrdata/data/train/fcne6.png
# /kaggle/input/customocrdata/data/train/8n56m.png
# /kaggle/input/customocrdata/data/train/dfnx4.png
# /kaggle/input/customocrdata/data/train/pybee.png
# /kaggle/input/customocrdata/data/train/gc83b.png
# /kaggle/input/customocrdata/data/train/7xd5m.png
# /kaggle/input/customocrdata/data/train/b4y5x.png
# /kaggle/input/customocrdata/data/train/38n57.png
# /kaggle/input/customocrdata/data/train/7dxbd.png
# /kaggle/input/customocrdata/data/train/ddcdd.png
# /kaggle/input/customocrdata/data/train/47e4p.png
# /kaggle/input/customocrdata/data/train/537nf.png
# /kaggle/input/customocrdata/data/train/ncww7.png
# /kaggle/input/customocrdata/data/train/e46pd.png
# /kaggle/input/customocrdata/data/train/37ep6.png
# /kaggle/input/customocrdata/data/train/wd2gb.png
# /kaggle/input/customocrdata/data/train/wye85.png
# /kaggle/input/customocrdata/data/train/md344.png
# /kaggle/input/customocrdata/data/train/pgmn2.png
# /kaggle/input/customocrdata/data/train/g3ex3.png
# /kaggle/input/customocrdata/data/train/g7wxw.png
# /kaggle/input/customocrdata/data/train/6fgdw.png
# /kaggle/input/customocrdata/data/train/36w25.png
# /kaggle/input/customocrdata/data/train/cen55.png
# /kaggle/input/customocrdata/data/train/832f3.png
# /kaggle/input/customocrdata/data/train/wwmn6.png
# /kaggle/input/customocrdata/data/train/6f2yc.png
# /kaggle/input/customocrdata/data/train/mm3nn.png
# /kaggle/input/customocrdata/data/train/f2fge.png
# /kaggle/input/customocrdata/data/train/d22y5.png
# /kaggle/input/customocrdata/data/train/ep85x.png
# /kaggle/input/customocrdata/data/train/e72cd.png
# /kaggle/input/customocrdata/data/train/68wfd.png
# /kaggle/input/customocrdata/data/train/mdxpn.png
# /kaggle/input/customocrdata/data/train/32dnn.png
# /kaggle/input/customocrdata/data/train/mye68.png
# /kaggle/input/customocrdata/data/train/5mcy7.png
# /kaggle/input/customocrdata/data/train/7cdge.png
# /kaggle/input/customocrdata/data/train/pdw38.png
# /kaggle/input/customocrdata/data/train/43xfe.png
# /kaggle/input/customocrdata/data/train/76n7p.png
# /kaggle/input/customocrdata/data/train/c43b4.png
# /kaggle/input/customocrdata/data/train/pcm7f.png
# /kaggle/input/customocrdata/data/train/8cm46.png
# /kaggle/input/customocrdata/data/train/2mpnn.png
# /kaggle/input/customocrdata/data/train/pnmxf.png
# /kaggle/input/customocrdata/data/train/3n3cf.png
# /kaggle/input/customocrdata/data/train/fp3wy.png
# /kaggle/input/customocrdata/data/train/3cpwb.png
# /kaggle/input/customocrdata/data/train/6p7gx.png
# /kaggle/input/customocrdata/data/train/nny5e.png
# /kaggle/input/customocrdata/data/train/cnex4.png
# /kaggle/input/customocrdata/data/train/g78gn.png
# /kaggle/input/customocrdata/data/train/f7cey.png
# /kaggle/input/customocrdata/data/train/m5ym2.png
# /kaggle/input/customocrdata/data/train/28348.png
# /kaggle/input/customocrdata/data/train/b3xpn.png
# /kaggle/input/customocrdata/data/train/7g3nf.png
# /kaggle/input/customocrdata/data/train/pxne8.png
# /kaggle/input/customocrdata/data/train/8npe3.png
# /kaggle/input/customocrdata/data/train/cwgyx.png
# /kaggle/input/customocrdata/data/train/5x7x5.png
# /kaggle/input/customocrdata/data/train/5bb66.png
# /kaggle/input/customocrdata/data/train/w8f36.png
# /kaggle/input/customocrdata/data/train/68x48.png
# /kaggle/input/customocrdata/data/train/x347n.png
# /kaggle/input/customocrdata/data/train/een23.png
# /kaggle/input/customocrdata/data/train/cc845.png
# /kaggle/input/customocrdata/data/train/xcf88.png
# /kaggle/input/customocrdata/data/train/7b4bm.png
# /kaggle/input/customocrdata/data/train/22d5n.png
# /kaggle/input/customocrdata/data/train/fpw76.png
# /kaggle/input/customocrdata/data/train/n6f4b.png
# /kaggle/input/customocrdata/data/train/84w7x.png
# /kaggle/input/customocrdata/data/train/b2nen.png
# /kaggle/input/customocrdata/data/train/e43ym.png
# /kaggle/input/customocrdata/data/train/6ge3p.png
# /kaggle/input/customocrdata/data/train/573bn.png
# /kaggle/input/customocrdata/data/train/33n73.png
# /kaggle/input/customocrdata/data/train/m2576.png
# /kaggle/input/customocrdata/data/train/53wb8.png
# /kaggle/input/customocrdata/data/train/25p2m.png
# /kaggle/input/customocrdata/data/train/cdf77.png
# /kaggle/input/customocrdata/data/train/7bb7b.png
# /kaggle/input/customocrdata/data/train/wxcn8.png
# /kaggle/input/customocrdata/data/train/ypw3d.png
# /kaggle/input/customocrdata/data/train/ccf2w.png
# /kaggle/input/customocrdata/data/train/57gnx.png
# /kaggle/input/customocrdata/data/train/76nxn.png
# /kaggle/input/customocrdata/data/train/xw465.png
# /kaggle/input/customocrdata/data/train/cnmnn.png
# /kaggle/input/customocrdata/data/train/w7e6m.png
# /kaggle/input/customocrdata/data/train/c4mcm.png
# /kaggle/input/customocrdata/data/train/cg5dd.png
# /kaggle/input/customocrdata/data/train/c6f8g.png
# /kaggle/input/customocrdata/data/train/6wb76.png
# /kaggle/input/customocrdata/data/train/xbcbx.png
# /kaggle/input/customocrdata/data/train/w52fn.png
# /kaggle/input/customocrdata/data/train/8b735.png
# /kaggle/input/customocrdata/data/train/4n2yg.png
# /kaggle/input/customocrdata/data/train/8y63f.png
# /kaggle/input/customocrdata/data/train/n5cm7.png
# /kaggle/input/customocrdata/data/train/6ng6w.png
# /kaggle/input/customocrdata/data/train/nm46n.png
# /kaggle/input/customocrdata/data/train/3fbxd.png
# /kaggle/input/customocrdata/data/train/fxpw3.png
# /kaggle/input/customocrdata/data/train/f22bn.png
# /kaggle/input/customocrdata/data/train/3bd8f.png
# /kaggle/input/customocrdata/data/train/33b22.png
# /kaggle/input/customocrdata/data/train/25egp.png
# /kaggle/input/customocrdata/data/train/w4nfx.png
# /kaggle/input/customocrdata/data/train/pmg55.png
# /kaggle/input/customocrdata/data/train/bgem5.png
# /kaggle/input/customocrdata/data/train/5gcd3.png
# /kaggle/input/customocrdata/data/train/mw5p2.png
# /kaggle/input/customocrdata/data/train/2en7g.png
# /kaggle/input/customocrdata/data/train/f8f8g.png
# /kaggle/input/customocrdata/data/train/n8pfe.png
# /kaggle/input/customocrdata/data/train/53wp3.png
# /kaggle/input/customocrdata/data/train/65nmw.jpg
# /kaggle/input/customocrdata/data/train/pwmbn.png
# /kaggle/input/customocrdata/data/train/mggce.png
# /kaggle/input/customocrdata/data/train/m4g8g.png
# /kaggle/input/customocrdata/data/train/8gmnx.png
# /kaggle/input/customocrdata/data/train/yw7ny.png
# /kaggle/input/customocrdata/data/train/6c3p5.png
# /kaggle/input/customocrdata/data/train/d3ycn.png
# /kaggle/input/customocrdata/data/train/p6mn8.png
# /kaggle/input/customocrdata/data/train/m5meg.png
# /kaggle/input/customocrdata/data/train/p2x7x.png
# /kaggle/input/customocrdata/data/train/ewnx8.png
# /kaggle/input/customocrdata/data/train/pe4xn.png
# /kaggle/input/customocrdata/data/train/pme86.png
# /kaggle/input/customocrdata/data/train/m8gmx.png
# /kaggle/input/customocrdata/data/train/nbcgb.png
# /kaggle/input/customocrdata/data/train/7xcyd.png
# /kaggle/input/customocrdata/data/train/b4ncn.png
# /kaggle/input/customocrdata/data/train/yw8y5.jpg
# /kaggle/input/customocrdata/data/train/cfc2y.png
# /kaggle/input/customocrdata/data/train/wxy4n.png
# /kaggle/input/customocrdata/data/train/8pfxx.png
# /kaggle/input/customocrdata/data/train/yy824.png
# /kaggle/input/customocrdata/data/train/eng53.png
# /kaggle/input/customocrdata/data/train/3bfnd.png
# /kaggle/input/customocrdata/data/train/f74x3.png
# /kaggle/input/customocrdata/data/train/7nnnx.png
# /kaggle/input/customocrdata/data/train/8nn73.png
# /kaggle/input/customocrdata/data/train/wf684.png
# /kaggle/input/customocrdata/data/train/3nfdn.png
# /kaggle/input/customocrdata/data/train/4dgf7.png
# /kaggle/input/customocrdata/data/train/d236n.png
# /kaggle/input/customocrdata/data/train/x775w.png
# /kaggle/input/customocrdata/data/train/w2n7e.png
# /kaggle/input/customocrdata/data/train/8gecm.png
# /kaggle/input/customocrdata/data/train/8bbw8.png
# /kaggle/input/customocrdata/data/train/488de.png
# /kaggle/input/customocrdata/data/train/3x5fm.png
# /kaggle/input/customocrdata/data/train/wddcp.png
# /kaggle/input/customocrdata/data/train/b35f6.png
# /kaggle/input/customocrdata/data/train/yd38e.png
# /kaggle/input/customocrdata/data/train/fnbfw.png
# /kaggle/input/customocrdata/data/train/34pcn.png
# /kaggle/input/customocrdata/data/train/n7g4f.png
# /kaggle/input/customocrdata/data/train/8n5p3.png
# /kaggle/input/customocrdata/data/train/5p3mm.png
# /kaggle/input/customocrdata/data/train/nfg23.png
# /kaggle/input/customocrdata/data/train/p8wwf.png
# /kaggle/input/customocrdata/data/train/34fxm.png
# /kaggle/input/customocrdata/data/train/m2nf4.png
# /kaggle/input/customocrdata/data/train/4433m.png
# /kaggle/input/customocrdata/data/train/6bxwg.png
# /kaggle/input/customocrdata/data/train/cm6yb.png
# /kaggle/input/customocrdata/data/train/y4g3b.png
# /kaggle/input/customocrdata/data/train/deep5.png
# /kaggle/input/customocrdata/data/train/6f857.png
# /kaggle/input/customocrdata/data/train/mgdwb.png
# /kaggle/input/customocrdata/data/train/bp6mw.png
# /kaggle/input/customocrdata/data/train/b26nd.png
# /kaggle/input/customocrdata/data/train/ygfwe.png
# /kaggle/input/customocrdata/data/train/gnbde.png
# /kaggle/input/customocrdata/data/train/ncfgb.png
# /kaggle/input/customocrdata/data/train/d378n.png
# /kaggle/input/customocrdata/data/train/ny8np.png
# /kaggle/input/customocrdata/data/train/dn2ym.png
# /kaggle/input/customocrdata/data/train/243mm.png
# /kaggle/input/customocrdata/data/train/gd4mf.png
# /kaggle/input/customocrdata/data/train/y53c2.png
# /kaggle/input/customocrdata/data/train/yxd7m.png
# /kaggle/input/customocrdata/data/train/5wddw.png
# /kaggle/input/customocrdata/data/train/3nnpw.png
# /kaggle/input/customocrdata/data/train/e2d66.png
# /kaggle/input/customocrdata/data/train/m3588.png
# /kaggle/input/customocrdata/data/train/d3c7y.png
# /kaggle/input/customocrdata/data/train/nbfx5.png
# /kaggle/input/customocrdata/data/train/nnp4e.png
# /kaggle/input/customocrdata/data/train/8n5pn.png
# /kaggle/input/customocrdata/data/train/my84e.png
# /kaggle/input/customocrdata/data/train/gm6nn.png
# /kaggle/input/customocrdata/data/train/55w5c.png
# /kaggle/input/customocrdata/data/train/w2yp7.png
# /kaggle/input/customocrdata/data/train/bnc5f.png
# /kaggle/input/customocrdata/data/train/ccn2x.png
# /kaggle/input/customocrdata/data/train/4cn7b.png
# /kaggle/input/customocrdata/data/train/fcey3.png
# /kaggle/input/customocrdata/data/train/n373n.png
# /kaggle/input/customocrdata/data/train/2wx73.png
# /kaggle/input/customocrdata/data/train/4b2pw.png
# /kaggle/input/customocrdata/data/train/b4ndb.jpg
# /kaggle/input/customocrdata/data/train/467d5.png
# /kaggle/input/customocrdata/data/train/nw5b2.png
# /kaggle/input/customocrdata/data/train/5dxnm.png
# /kaggle/input/customocrdata/data/train/4dw3w.png
# /kaggle/input/customocrdata/data/train/x4f7g.png
# /kaggle/input/customocrdata/data/train/gw468.png
# /kaggle/input/customocrdata/data/train/33ng4.png
# /kaggle/input/customocrdata/data/train/wmpmp.png
# /kaggle/input/customocrdata/data/train/f6ww8.png
# /kaggle/input/customocrdata/data/train/ygce8.jpg
# /kaggle/input/customocrdata/data/train/p2m6n.png
# /kaggle/input/customocrdata/data/train/nnf8b.png
# /kaggle/input/customocrdata/data/train/nwfde.png
# /kaggle/input/customocrdata/data/train/xnfx5.png
# /kaggle/input/customocrdata/data/train/c8n8c.png
# /kaggle/input/customocrdata/data/train/377xx.png
# /kaggle/input/customocrdata/data/train/728n8.png
# /kaggle/input/customocrdata/data/train/p57fn.png
# /kaggle/input/customocrdata/data/train/4m2w5.png
# /kaggle/input/customocrdata/data/train/xf4p4.png
# /kaggle/input/customocrdata/data/train/bxxfc.png
# /kaggle/input/customocrdata/data/train/n464c.png
# /kaggle/input/customocrdata/data/train/xxney.png
# /kaggle/input/customocrdata/data/train/yyn57.png
# /kaggle/input/customocrdata/data/train/wb3ed.png
# /kaggle/input/customocrdata/data/train/mbp2y.png
# /kaggle/input/customocrdata/data/train/mgw3n.png
# /kaggle/input/customocrdata/data/train/f83pn.png
# /kaggle/input/customocrdata/data/train/5n245.png
# /kaggle/input/customocrdata/data/train/8g4yp.png
# /kaggle/input/customocrdata/data/train/84py4.jpg
# /kaggle/input/customocrdata/data/train/88y52.png
# /kaggle/input/customocrdata/data/train/34b84.png
# /kaggle/input/customocrdata/data/train/3mxdn.png
# /kaggle/input/customocrdata/data/train/4w76g.png
# /kaggle/input/customocrdata/data/train/2nf26.png
# /kaggle/input/customocrdata/data/train/edwny.png
# /kaggle/input/customocrdata/data/train/677g3.png
# /kaggle/input/customocrdata/data/train/mbf58.png
# /kaggle/input/customocrdata/data/train/fg8n4.png
# /kaggle/input/customocrdata/data/train/x3deb.png
# /kaggle/input/customocrdata/data/train/ppx77.png
# /kaggle/input/customocrdata/data/train/pdyc8.png
# /kaggle/input/customocrdata/data/train/2b827.png
# /kaggle/input/customocrdata/data/train/662bw.png
# /kaggle/input/customocrdata/data/train/c2pg6.png
# /kaggle/input/customocrdata/data/train/e2mg2.png
# /kaggle/input/customocrdata/data/train/5fyem.png
# /kaggle/input/customocrdata/data/train/3ndxd.png
# /kaggle/input/customocrdata/data/train/w48cw.png
# /kaggle/input/customocrdata/data/train/wgnwp.png
# /kaggle/input/customocrdata/data/train/d2ycw.png
# /kaggle/input/customocrdata/data/train/8wy7d.png
# /kaggle/input/customocrdata/data/train/cfc56.png
# /kaggle/input/customocrdata/data/train/m75bf.png
# /kaggle/input/customocrdata/data/train/y866y.png
# /kaggle/input/customocrdata/data/train/nf2n8.png
# /kaggle/input/customocrdata/data/train/m3b5p.png
# /kaggle/input/customocrdata/data/train/dce8y.png
# /kaggle/input/customocrdata/data/train/xngxc.png
# /kaggle/input/customocrdata/data/train/dd764.png
# /kaggle/input/customocrdata/data/train/by5y3.png
# /kaggle/input/customocrdata/data/train/ydg8n.png
# /kaggle/input/customocrdata/data/train/3x325.png
# /kaggle/input/customocrdata/data/train/fyfbn.png
# /kaggle/input/customocrdata/data/train/57b27.png
# /kaggle/input/customocrdata/data/train/6g45w.png
# /kaggle/input/customocrdata/data/train/6fg8c.png
# /kaggle/input/customocrdata/data/train/56c34.png
# /kaggle/input/customocrdata/data/train/mddgb.png
# /kaggle/input/customocrdata/data/train/y3c58.png
# /kaggle/input/customocrdata/data/train/nxf2c.jpg
# /kaggle/input/customocrdata/data/train/6cwxe.png
# /kaggle/input/customocrdata/data/train/678w3.png
# /kaggle/input/customocrdata/data/train/efb3f.png
# /kaggle/input/customocrdata/data/train/5x5nx.png
# /kaggle/input/customocrdata/data/train/gw53m.png
# /kaggle/input/customocrdata/data/train/g2577.png
# /kaggle/input/customocrdata/data/train/yeyn4.png
# /kaggle/input/customocrdata/data/train/2356g.png
# /kaggle/input/customocrdata/data/train/d3c8y.png
# /kaggle/input/customocrdata/data/train/yx2d4.png
# /kaggle/input/customocrdata/data/train/w46ep.png
# /kaggle/input/customocrdata/data/train/dbpcd.png
# /kaggle/input/customocrdata/data/train/3pe4g.png
# /kaggle/input/customocrdata/data/train/gcx6f.png
# /kaggle/input/customocrdata/data/train/ng46m.png
# /kaggle/input/customocrdata/data/train/8n62n.png
# /kaggle/input/customocrdata/data/train/nxcmn.png
# /kaggle/input/customocrdata/data/train/42dw4.png
# /kaggle/input/customocrdata/data/train/3xng6.png
# /kaggle/input/customocrdata/data/train/y7d75.png
# /kaggle/input/customocrdata/data/train/n7meb.png
# /kaggle/input/customocrdata/data/train/dnne7.png
# /kaggle/input/customocrdata/data/train/78eec.png
# /kaggle/input/customocrdata/data/train/ddmyg.png
# /kaggle/input/customocrdata/data/train/8y6b3.png
# /kaggle/input/customocrdata/data/train/mnef5.png
# /kaggle/input/customocrdata/data/train/deneb.png
# /kaggle/input/customocrdata/data/train/mcc2x.png
# /kaggle/input/customocrdata/data/train/x4pnp.png
# /kaggle/input/customocrdata/data/train/ndecc.png
# /kaggle/input/customocrdata/data/train/5mf7c.png
# /kaggle/input/customocrdata/data/train/5np4m.png
# /kaggle/input/customocrdata/data/train/mn5c4.png
# /kaggle/input/customocrdata/data/train/253dc.png
# /kaggle/input/customocrdata/data/train/ymp7g.png
# /kaggle/input/customocrdata/data/train/325fb.png
# /kaggle/input/customocrdata/data/train/gnf85.png
# /kaggle/input/customocrdata/data/train/bw5nf.png
# /kaggle/input/customocrdata/data/train/3d7bd.png
# /kaggle/input/customocrdata/data/train/bf52c.png
# /kaggle/input/customocrdata/data/train/bcwnn.png
# /kaggle/input/customocrdata/data/train/n265y.png
# /kaggle/input/customocrdata/data/train/mc35n.png
# /kaggle/input/customocrdata/data/train/dmxp8.png
# /kaggle/input/customocrdata/data/train/65m85.png
# /kaggle/input/customocrdata/data/train/defyx.png
# /kaggle/input/customocrdata/data/train/5nggg.png
# /kaggle/input/customocrdata/data/train/mx8bb.png
# /kaggle/input/customocrdata/data/train/n7dyb.png
# /kaggle/input/customocrdata/data/train/ngn26.png
# /kaggle/input/customocrdata/data/train/ndme7.png
# /kaggle/input/customocrdata/data/train/c7gb3.png
# /kaggle/input/customocrdata/data/train/neggn.png
# /kaggle/input/customocrdata/data/train/3p4nn.png
# /kaggle/input/customocrdata/data/train/gf2g4.png
# /kaggle/input/customocrdata/data/train/n336e.png
# /kaggle/input/customocrdata/data/train/exycn.png
# /kaggle/input/customocrdata/data/train/4c8n8.png
# /kaggle/input/customocrdata/data/train/445cc.png
# /kaggle/input/customocrdata/data/train/42nxy.png
# /kaggle/input/customocrdata/data/train/dmw8n.png
# /kaggle/input/customocrdata/data/train/dyxnc.png
# /kaggle/input/customocrdata/data/train/2x7bm.png
# /kaggle/input/customocrdata/data/train/y5w28.png
# /kaggle/input/customocrdata/data/train/ddnpf.png
# /kaggle/input/customocrdata/data/train/c353e.png
# /kaggle/input/customocrdata/data/train/7gp47.png
# /kaggle/input/customocrdata/data/train/g7gnf.png
# /kaggle/input/customocrdata/data/train/xgcxy.png
# /kaggle/input/customocrdata/data/train/dn5df.png
# /kaggle/input/customocrdata/data/train/pm47f.png
# /kaggle/input/customocrdata/data/train/myf82.png
# /kaggle/input/customocrdata/data/train/pgwnp.png
# /kaggle/input/customocrdata/data/train/nfbg8.png
# /kaggle/input/customocrdata/data/train/8nbew.png
# /kaggle/input/customocrdata/data/train/d7nn3.png
# /kaggle/input/customocrdata/data/train/mmfm6.png
# /kaggle/input/customocrdata/data/train/e5n66.png
# /kaggle/input/customocrdata/data/train/w4cnn.png
# /kaggle/input/customocrdata/data/train/cpc8c.png
# /kaggle/input/customocrdata/data/train/ffpxf.png
# /kaggle/input/customocrdata/data/train/w6yne.png
# /kaggle/input/customocrdata/data/train/b685n.png
# /kaggle/input/customocrdata/data/train/6825y.png
# /kaggle/input/customocrdata/data/train/n2c85.jpg
# /kaggle/input/customocrdata/data/train/f75cx.png
# /kaggle/input/customocrdata/data/train/gnc3n.png
# /kaggle/input/customocrdata/data/train/8ypdn.png
# /kaggle/input/customocrdata/data/train/emwpn.png
# /kaggle/input/customocrdata/data/train/3n2b4.png
# /kaggle/input/customocrdata/data/train/mg5nn.png
# /kaggle/input/customocrdata/data/train/3bx86.png
# /kaggle/input/customocrdata/data/train/2p2y8.png
# /kaggle/input/customocrdata/data/train/e8dxn.png
# /kaggle/input/customocrdata/data/train/368y5.png
# /kaggle/input/customocrdata/data/train/6dd2y.png
# /kaggle/input/customocrdata/data/train/ny3dw.png
# /kaggle/input/customocrdata/data/train/excmn.png
# /kaggle/input/customocrdata/data/train/5bg8f.png
# /kaggle/input/customocrdata/data/train/gc2wd.png
# /kaggle/input/customocrdata/data/train/b43nw.png
# /kaggle/input/customocrdata/data/train/6mn8n.png
# /kaggle/input/customocrdata/data/train/p5nce.png
# /kaggle/input/customocrdata/data/train/8db67.png
# /kaggle/input/customocrdata/data/train/mfb3x.png
# /kaggle/input/customocrdata/data/train/ddcne.png
# /kaggle/input/customocrdata/data/train/ncw4g.png
# /kaggle/input/customocrdata/data/train/byfgn.png
# /kaggle/input/customocrdata/data/train/bwmee.png
# /kaggle/input/customocrdata/data/train/y5n6d.png
# /kaggle/input/customocrdata/data/train/eppg3.png
# /kaggle/input/customocrdata/data/train/6end3.png
# /kaggle/input/customocrdata/data/train/ennmm.png
# /kaggle/input/customocrdata/data/train/2n73f.png
# /kaggle/input/customocrdata/data/train/gm7n8.png
# /kaggle/input/customocrdata/data/train/7pn5g.png
# /kaggle/input/customocrdata/data/train/egxmp.png
# /kaggle/input/customocrdata/data/train/5ep3n.png
# /kaggle/input/customocrdata/data/train/5xd2e.png
# /kaggle/input/customocrdata/data/train/55y2m.png
# /kaggle/input/customocrdata/data/train/44xe8.png
# /kaggle/input/customocrdata/data/train/fywb8.png
# /kaggle/input/customocrdata/data/train/c86md.png
# /kaggle/input/customocrdata/data/train/n3bm6.png
# /kaggle/input/customocrdata/data/train/d666m.png
# /kaggle/input/customocrdata/data/train/dbex3.png
# /kaggle/input/customocrdata/data/train/6wnyc.png
# /kaggle/input/customocrdata/data/train/6cm6m.png
# /kaggle/input/customocrdata/data/train/bbymy.png
# /kaggle/input/customocrdata/data/train/72m6f.png
# /kaggle/input/customocrdata/data/train/4fp5g.png
# /kaggle/input/customocrdata/data/train/byc82.png
# /kaggle/input/customocrdata/data/train/xnn4d.png
# /kaggle/input/customocrdata/data/train/675p3.png
# /kaggle/input/customocrdata/data/train/cd6p4.png
# /kaggle/input/customocrdata/data/train/bny4w.png
# /kaggle/input/customocrdata/data/train/62nb3.png
# /kaggle/input/customocrdata/data/train/2nx38.png
# /kaggle/input/customocrdata/data/train/x8xnp.png
# /kaggle/input/customocrdata/data/train/5g5e5.png
# /kaggle/input/customocrdata/data/train/4gb3f.png
# /kaggle/input/customocrdata/data/train/m23bp.png
# /kaggle/input/customocrdata/data/train/66wp5.png
# /kaggle/input/customocrdata/data/train/85pew.jpg
# /kaggle/input/customocrdata/data/train/56ncx.png
# /kaggle/input/customocrdata/data/train/x5f54.png
# /kaggle/input/customocrdata/data/train/yf424.png
# /kaggle/input/customocrdata/data/train/x277e.png
# /kaggle/input/customocrdata/data/train/dnxdp.png
# /kaggle/input/customocrdata/data/train/n4wwn.png
# /kaggle/input/customocrdata/data/train/7wnpm.png
# /kaggle/input/customocrdata/data/train/y5g87.png
# /kaggle/input/customocrdata/data/train/m67b3.png
# /kaggle/input/customocrdata/data/train/ng2gw.png
# /kaggle/input/customocrdata/data/train/7p852.png
# /kaggle/input/customocrdata/data/train/efe62.png
# /kaggle/input/customocrdata/data/train/nfcwy.png
# /kaggle/input/customocrdata/data/train/2nbc5.jpg
# /kaggle/input/customocrdata/data/train/be6np.png
# /kaggle/input/customocrdata/data/train/px2xp.png
# /kaggle/input/customocrdata/data/train/7634y.png
# /kaggle/input/customocrdata/data/train/bd3b7.png
# /kaggle/input/customocrdata/data/train/245y5.png
# /kaggle/input/customocrdata/data/train/gymmn.png
# /kaggle/input/customocrdata/data/train/x5nyn.png
# /kaggle/input/customocrdata/data/train/373gb.png
# /kaggle/input/customocrdata/data/train/82fx2.png
# /kaggle/input/customocrdata/data/train/g55b4.png
# /kaggle/input/customocrdata/data/train/nbf8m.png
# /kaggle/input/customocrdata/data/train/28x47.png
# /kaggle/input/customocrdata/data/train/n3x4c.png
# /kaggle/input/customocrdata/data/train/yfdn7.png
# /kaggle/input/customocrdata/data/train/8cccc.png
# /kaggle/input/customocrdata/data/train/bx5ed.jpg
# /kaggle/input/customocrdata/data/train/gwn53.png
# /kaggle/input/customocrdata/data/train/xce8d.png
# /kaggle/input/customocrdata/data/train/y2ye8.png
# /kaggle/input/customocrdata/data/train/gng6e.png
# /kaggle/input/customocrdata/data/train/d8xcn.png
# /kaggle/input/customocrdata/data/train/pmd3w.png
# /kaggle/input/customocrdata/data/train/nc4yg.png
# /kaggle/input/customocrdata/data/train/226md.png
# /kaggle/input/customocrdata/data/train/enn7n.png
# /kaggle/input/customocrdata/data/train/mc8w2.png
# /kaggle/input/customocrdata/data/train/x7422.png
# /kaggle/input/customocrdata/data/train/mwxwp.png
# /kaggle/input/customocrdata/data/train/xfg65.png
# /kaggle/input/customocrdata/data/train/8n4n8.png
# /kaggle/input/customocrdata/data/train/24f6w.png
# /kaggle/input/customocrdata/data/train/gny6b.png
# /kaggle/input/customocrdata/data/train/44c22.png
# /kaggle/input/customocrdata/data/train/478nx.png
# /kaggle/input/customocrdata/data/train/wnmyn.png
# /kaggle/input/customocrdata/data/train/387g2.png
# /kaggle/input/customocrdata/data/train/4yc85.png
# /kaggle/input/customocrdata/data/train/cndmc.jpg
# /kaggle/input/customocrdata/data/train/6xen4.png
# /kaggle/input/customocrdata/data/train/ypp8f.png
# /kaggle/input/customocrdata/data/train/xyyyw.png
# /kaggle/input/customocrdata/data/train/mmg38.png
# /kaggle/input/customocrdata/data/train/823p2.png
# /kaggle/input/customocrdata/data/train/7f8b3.png
# /kaggle/input/customocrdata/data/train/p5g5m.png
# /kaggle/input/customocrdata/data/train/pcmcc.jpg
# /kaggle/input/customocrdata/data/train/5n3w4.png
# /kaggle/input/customocrdata/data/train/e7x45.png
# /kaggle/input/customocrdata/data/train/nfcb5.png
# /kaggle/input/customocrdata/data/train/wyc25.png
# /kaggle/input/customocrdata/data/train/dw3nn.png
# /kaggle/input/customocrdata/data/train/dy3cx.png
# /kaggle/input/customocrdata/data/train/xbem6.png
# /kaggle/input/customocrdata/data/train/7dyww.png
# /kaggle/input/customocrdata/data/train/3dgmf.png
# /kaggle/input/customocrdata/data/train/4743p.png
# /kaggle/input/customocrdata/data/train/cnwyc.png
# /kaggle/input/customocrdata/data/train/23mdg.png
# /kaggle/input/customocrdata/data/train/b28g8.png
# /kaggle/input/customocrdata/data/train/nwncn.png
# /kaggle/input/customocrdata/data/train/n8wxm.jpg
# /kaggle/input/customocrdata/data/train/e667x.png
# /kaggle/input/customocrdata/data/train/8c2wy.png
# /kaggle/input/customocrdata/data/train/n7ff2.png
# /kaggle/input/customocrdata/data/train/ec6pm.png
# /kaggle/input/customocrdata/data/train/y33nm.png
# /kaggle/input/customocrdata/data/train/6fn84.png
# /kaggle/input/customocrdata/data/train/3bnyf.png
# /kaggle/input/customocrdata/data/train/7pcd7.png
# /kaggle/input/customocrdata/data/train/neecd.png
# /kaggle/input/customocrdata/data/train/dc436.png
# /kaggle/input/customocrdata/data/train/b5fm7.png
# /kaggle/input/customocrdata/data/train/feyc8.png
# /kaggle/input/customocrdata/data/train/3ebnn.png
# /kaggle/input/customocrdata/data/train/6ng6n.png
# /kaggle/input/customocrdata/data/train/63pxe.png
# /kaggle/input/customocrdata/data/train/x7746.png
# /kaggle/input/customocrdata/data/train/c4bny.png
# /kaggle/input/customocrdata/data/train/8e32m.png
# /kaggle/input/customocrdata/data/train/ng6yp.png
# /kaggle/input/customocrdata/data/train/nm248.png
# /kaggle/input/customocrdata/data/train/dnmd8.png
# /kaggle/input/customocrdata/data/train/43mn5.png
# /kaggle/input/customocrdata/data/train/56m6y.png
# /kaggle/input/customocrdata/data/train/5f3gf.png
# /kaggle/input/customocrdata/data/train/pf4nb.png
# /kaggle/input/customocrdata/data/train/7wyp4.png
# /kaggle/input/customocrdata/data/train/x6pdb.png
# /kaggle/input/customocrdata/data/train/pmf5w.png
# /kaggle/input/customocrdata/data/train/yyg5g.png
# /kaggle/input/customocrdata/data/train/nbwnn.png
# /kaggle/input/customocrdata/data/train/7cgym.png
# /kaggle/input/customocrdata/data/train/4w6mw.png
# /kaggle/input/customocrdata/data/train/nd5wg.png
# /kaggle/input/customocrdata/data/train/c753e.png
# /kaggle/input/customocrdata/data/train/d7en3.png
# /kaggle/input/customocrdata/data/train/nnfx3.png
# /kaggle/input/customocrdata/data/train/4exnn.png
# /kaggle/input/customocrdata/data/train/p2dw7.png
# /kaggle/input/customocrdata/data/train/cewnm.png
# /kaggle/input/customocrdata/data/train/xp24p.png
# /kaggle/input/customocrdata/data/train/573d8.png
# /kaggle/input/customocrdata/data/train/nfd8g.png
# /kaggle/input/customocrdata/data/train/64m82.png
# /kaggle/input/customocrdata/data/train/8d4wm.png
# /kaggle/input/customocrdata/data/train/nwg2m.png
# /kaggle/input/customocrdata/data/train/dgcm4.jpg
# /kaggle/input/customocrdata/data/train/3g2w6.png
# /kaggle/input/customocrdata/data/train/gpxng.png
# /kaggle/input/customocrdata/data/train/w75w8.png
# /kaggle/input/customocrdata/data/train/y2xg4.png
# /kaggle/input/customocrdata/data/train/6mege.png
# /kaggle/input/customocrdata/data/train/gcfgp.png
# /kaggle/input/customocrdata/data/train/ddpyb.png
# /kaggle/input/customocrdata/data/train/4nc37.png
# /kaggle/input/customocrdata/data/train/556wd.png
# /kaggle/input/customocrdata/data/train/y5dpp.png
# /kaggle/input/customocrdata/data/train/58b5m.png
# /kaggle/input/customocrdata/data/train/5mnpd.png
# /kaggle/input/customocrdata/data/train/b84xc.png
# /kaggle/input/customocrdata/data/train/gbxyy.png
# /kaggle/input/customocrdata/data/train/e8e5e.png
# /kaggle/input/customocrdata/data/train/gmmne.jpg
# /kaggle/input/customocrdata/data/train/xfn6n.png
# /kaggle/input/customocrdata/data/train/b6f2p.png
# /kaggle/input/customocrdata/data/train/43gey.png
# /kaggle/input/customocrdata/data/train/cd4eg.png
# /kaggle/input/customocrdata/data/train/g7fmc.png
# /kaggle/input/customocrdata/data/train/65ebm.png
# /kaggle/input/customocrdata/data/train/d22n7.png
# /kaggle/input/customocrdata/data/train/p2ym2.png
# /kaggle/input/customocrdata/data/train/8c23f.png
# /kaggle/input/customocrdata/data/train/b4d7c.png
# /kaggle/input/customocrdata/data/train/ydd3g.png
# /kaggle/input/customocrdata/data/train/33p4e.png
# /kaggle/input/customocrdata/data/train/3nw7w.png
# /kaggle/input/customocrdata/data/train/6bnnm.png
# /kaggle/input/customocrdata/data/train/2nbcx.png
# /kaggle/input/customocrdata/data/train/4ycex.png
# /kaggle/input/customocrdata/data/train/gecmf.png
# /kaggle/input/customocrdata/data/train/fp5wn.png
# /kaggle/input/customocrdata/data/train/3xcgg.png
# /kaggle/input/customocrdata/data/train/wecfd.png
# /kaggle/input/customocrdata/data/train/7gce6.png
# /kaggle/input/customocrdata/data/train/gy433.png
# /kaggle/input/customocrdata/data/train/nxc83.png
# /kaggle/input/customocrdata/data/train/ewcf5.png
# /kaggle/input/customocrdata/data/train/d22bd.png
# /kaggle/input/customocrdata/data/train/2pfpn.png
# /kaggle/input/customocrdata/data/train/e25xg.png
# /kaggle/input/customocrdata/data/train/xxw44.png
# /kaggle/input/customocrdata/data/train/e6m6p.png
# /kaggle/input/customocrdata/data/train/6p2ge.png
# /kaggle/input/customocrdata/data/train/2xc2n.png
# /kaggle/input/customocrdata/data/train/f364x.png
# /kaggle/input/customocrdata/data/train/4cfw8.png
# /kaggle/input/customocrdata/data/train/57wdp.png
# /kaggle/input/customocrdata/data/train/f2m8n.png
# /kaggle/input/customocrdata/data/train/6e6pn.png
# /kaggle/input/customocrdata/data/train/cpe63.png
# /kaggle/input/customocrdata/data/train/ewyg7.jpg
# /kaggle/input/customocrdata/data/train/cfn53.png
# /kaggle/input/customocrdata/data/train/xemyg.png
# /kaggle/input/customocrdata/data/train/6ydyp.png
# /kaggle/input/customocrdata/data/train/6xxdx.png
# /kaggle/input/customocrdata/data/train/3c7de.jpg
# /kaggle/input/customocrdata/data/train/2ycn8.png
# /kaggle/input/customocrdata/data/train/xwx7d.png
# /kaggle/input/customocrdata/data/train/dn26n.png
# /kaggle/input/customocrdata/data/train/y4n6m.png
# /kaggle/input/customocrdata/data/train/378e5.png
# /kaggle/input/customocrdata/data/train/4gycb.png
# /kaggle/input/customocrdata/data/train/bdg84.png
# /kaggle/input/customocrdata/data/train/xcmbp.png
# /kaggle/input/customocrdata/data/train/m4fd8.png
# /kaggle/input/customocrdata/data/train/gdng3.png
# /kaggle/input/customocrdata/data/train/f6ne5.png
# /kaggle/input/customocrdata/data/train/2npg6.png
# /kaggle/input/customocrdata/data/train/w8bnx.png
# /kaggle/input/customocrdata/data/train/2cegf.png
# /kaggle/input/customocrdata/data/train/b2g8e.png
# /kaggle/input/customocrdata/data/train/p4nm4.png
# /kaggle/input/customocrdata/data/train/d75b5.png
# /kaggle/input/customocrdata/data/train/gm2c2.png
# /kaggle/input/customocrdata/data/train/mxnw4.png
# /kaggle/input/customocrdata/data/train/x37bf.png
# /kaggle/input/customocrdata/data/train/ffnxn.png
# /kaggle/input/customocrdata/data/train/244e2.png
# /kaggle/input/customocrdata/data/train/n5w5g.png
# /kaggle/input/customocrdata/data/train/enpw2.png
# /kaggle/input/customocrdata/data/train/fg7mg.png
# /kaggle/input/customocrdata/data/train/c2yn8.png
# /kaggle/input/customocrdata/data/train/nxxf8.png
# /kaggle/input/customocrdata/data/train/cy3nw.png
# /kaggle/input/customocrdata/data/train/8w754.png
# /kaggle/input/customocrdata/data/train/nybcx.png
# /kaggle/input/customocrdata/data/train/dxwcw.png
# /kaggle/input/customocrdata/data/train/36bc2.png
# /kaggle/input/customocrdata/data/train/6n6gg.png
# /kaggle/input/customocrdata/data/train/w6ny4.jpg
# /kaggle/input/customocrdata/data/train/3ny45.png
# /kaggle/input/customocrdata/data/train/fbp2c.png
# /kaggle/input/customocrdata/data/train/7gnge.png
# /kaggle/input/customocrdata/data/train/5n728.png
# /kaggle/input/customocrdata/data/train/8d8ep.png
# /kaggle/input/customocrdata/data/train/xnnc3.png
# /kaggle/input/customocrdata/data/train/fgb36.jpg
# /kaggle/input/customocrdata/data/train/5bgp2.png
# /kaggle/input/customocrdata/data/train/8fexn.png
# /kaggle/input/customocrdata/data/train/ffd6p.png
# /kaggle/input/customocrdata/data/train/gxx2p.png
# /kaggle/input/customocrdata/data/train/gxxpf.png
# /kaggle/input/customocrdata/data/train/n4xx5.png
# /kaggle/input/customocrdata/data/train/c3572.png
# /kaggle/input/customocrdata/data/train/24pew.png
# /kaggle/input/customocrdata/data/train/ndg2b.png
# /kaggle/input/customocrdata/data/train/6pwcn.png
# /kaggle/input/customocrdata/data/train/8bbm4.png
# /kaggle/input/customocrdata/data/train/ncyx8.png
# /kaggle/input/customocrdata/data/train/7dwx4.png
# /kaggle/input/customocrdata/data/train/3b4we.png
# /kaggle/input/customocrdata/data/train/3ebpw.png
# /kaggle/input/customocrdata/data/train/3wnd3.png
# /kaggle/input/customocrdata/data/train/en4n4.png
# /kaggle/input/customocrdata/data/train/mpmy5.png
# /kaggle/input/customocrdata/data/train/cfp86.png
# /kaggle/input/customocrdata/data/train/8gf7n.png
# /kaggle/input/customocrdata/data/train/x38fn.png
# /kaggle/input/customocrdata/data/train/bw5ym.png
# /kaggle/input/customocrdata/data/train/y7mnm.png
# /kaggle/input/customocrdata/data/train/mmc5n.png
# /kaggle/input/customocrdata/data/train/ny5dp.png
# /kaggle/input/customocrdata/data/train/yd3m3.png
# /kaggle/input/customocrdata/data/train/pm363.png
# /kaggle/input/customocrdata/data/train/e6b7y.png
# /kaggle/input/customocrdata/data/train/n4b4m.png
# /kaggle/input/customocrdata/data/train/fp382.png
# /kaggle/input/customocrdata/data/train/d2n8x.jpg
# /kaggle/input/customocrdata/data/train/6e554.png
# /kaggle/input/customocrdata/data/train/xmcym.png
# /kaggle/input/customocrdata/data/train/75pfw.png
# /kaggle/input/customocrdata/data/train/264m5.png
# /kaggle/input/customocrdata/data/train/fncnb.png
# /kaggle/input/customocrdata/data/train/pyf65.png
# /kaggle/input/customocrdata/data/train/yew6p.png
# /kaggle/input/customocrdata/data/train/m448b.png
# /kaggle/input/customocrdata/data/train/ygenn.png
# /kaggle/input/customocrdata/data/train/pyefb.png
# /kaggle/input/customocrdata/data/train/e3cfe.jpg
# /kaggle/input/customocrdata/data/train/3w2bw.png
# /kaggle/input/customocrdata/data/train/pgg3n.png
# /kaggle/input/customocrdata/data/train/428b6.png
# /kaggle/input/customocrdata/data/train/42xpy.png
# /kaggle/input/customocrdata/data/train/76353.png
# /kaggle/input/customocrdata/data/train/8gmc4.png
# /kaggle/input/customocrdata/data/train/nf7bn.png
# /kaggle/input/customocrdata/data/train/pnnwy.png
# /kaggle/input/customocrdata/data/train/b5dn4.png
# /kaggle/input/customocrdata/data/train/62fgn.jpg
# /kaggle/input/customocrdata/data/train/pg2yx.png
# /kaggle/input/customocrdata/data/train/gc277.png
# /kaggle/input/customocrdata/data/train/fc2ff.png
# /kaggle/input/customocrdata/data/train/dw8d3.png
# /kaggle/input/customocrdata/data/train/nbmx7.png
# /kaggle/input/customocrdata/data/train/474ff.png
# /kaggle/input/customocrdata/data/train/d66cn.png
# /kaggle/input/customocrdata/data/train/c3n8x.png
# /kaggle/input/customocrdata/data/train/ng756.png
# /kaggle/input/customocrdata/data/train/cgcgb.png
# /kaggle/input/customocrdata/data/train/ef4np.png
# /kaggle/input/customocrdata/data/train/pcpg6.png
# /kaggle/input/customocrdata/data/train/4f8yp.png
# /kaggle/input/customocrdata/data/train/4nnf3.png
# /kaggle/input/customocrdata/data/train/w4x2m.png
# /kaggle/input/customocrdata/data/train/d8dce.png
# /kaggle/input/customocrdata/data/train/7gmf3.png
# /kaggle/input/customocrdata/data/train/nmw46.png
# /kaggle/input/customocrdata/data/train/5ywwf.png
# /kaggle/input/customocrdata/data/train/e3ndn.png
# /kaggle/input/customocrdata/data/train/x8e8n.png
# /kaggle/input/customocrdata/data/train/n5x2n.png
# /kaggle/input/customocrdata/data/train/npxb7.png
# /kaggle/input/customocrdata/data/sample/2b827.png

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(0)

# %%
def plot_loss(epoch: int, 
              train_losses: list, 
              val_losses: list, 
              n_steps: int = 100):
    
    # clear previous graph
    clear_output(True)
    # making titles
    train_title = f'Epoch:{epoch} | Train Loss:{np.mean(train_losses[-n_steps:]):.6f}'
    val_title = f'Epoch:{epoch} | Val Loss:{np.mean(val_losses[-n_steps:]):.6f}'

    fig, ax = plt.subplots(1, 2, figsize=(12, 6))
    ax[0].plot(train_losses)
    ax[1].plot(val_losses)

    ax[0].set_title(train_title)
    ax[1].set_title(val_title)

    plt.show()

def print_prediction(model, dataset, device, label_converter):
    idx = np.random.randint(len(dataset))
    path = dataset.pathes[idx]
    
    with torch.no_grad():
        model.eval()
        img, target_text = dataset[idx]
        img = img.unsqueeze(0)
        logits = model(img.to(device))
        
    pred_text = decode_prediction(logits.cpu(), label_converter)

    img = np.asarray(Image.open(path).convert('L'))
    title = f'Truth: {target_text} | Pred: {pred_text}'
    plt.imshow(img)
    plt.title(title)
    plt.axis('off');

# %%
class strLabelConverter(object):

    def __init__(self, alphabet: str, ignore_case: bool = True):
        self._ignore_case = ignore_case
        if self._ignore_case:
            alphabet = alphabet.lower()
        self.alphabet = alphabet + '-'  # for `-1` index

        self.char2idx = {}
        for i, char in enumerate(alphabet):
            self.char2idx[char] = i + 1
        self.idx2char = {idx: char for char, idx in self.char2idx.items()}

    def encode(self, text):
        if isinstance(text, str):
            text = [
                self.char2idx[char.lower() if self._ignore_case else char]
                for char in text
            ]
            length = [len(text)]
        elif isinstance(text, collections.Iterable):
            length = [len(s) for s in text]
            text = ''.join(text)
            text, _ = self.encode(text)
        return (torch.IntTensor(text), torch.IntTensor(length))

    def decode(self, t, length, raw=False):
        if length.numel() == 1:
            length = length[0]
            assert t.numel() == length, "text with length: {} does not match declared length: {}".format(t.numel(), length)
            if raw:
                return ''.join([self.alphabet[i - 1] for i in t])
            else:
                char_list = []
                for i in range(length):
                    if t[i] != 0 and (not (i > 0 and t[i - 1] == t[i])):
                        char_list.append(self.alphabet[t[i] - 1])
                return ''.join(char_list)
        else:
            # batch mode
            assert t.numel() == length.sum(), "texts with length: {} does not match declared length: {}".format(t.numel(), length.sum())
            texts = []
            index = 0
            for i in range(length.numel()):
                l = length[i]
                texts.append(
                    self.decode(
                        t[index:index + l], torch.IntTensor([l]), raw=raw))
                index += l
        return texts


def decode_prediction(logits: torch.Tensor, 
                      label_converter: strLabelConverter) -> str:
    tokens = logits.softmax(2).argmax(2)
    tokens = tokens.squeeze(1).numpy()
    
    # convert tor stings tokens
    tokens = ''.join([label_converter.idx2char[token] 
                      if token != 0  else '-' 
                      for token in tokens])
    tokens = tokens.split('-')
    
    # remove duplicates
    text = [char 
            for batch_token in tokens 
            for idx, char in enumerate(batch_token)
            if char != batch_token[idx-1] or len(batch_token) == 1]
    text = ''.join(text)
    return text

# %%
class blockCNN(nn.Module):
    def __init__(self, in_nc, out_nc, kernel_size, padding, stride=1):
        super(blockCNN, self).__init__()
        self.in_nc = in_nc
        self.out_nc = out_nc
        self.kernel_size = kernel_size
        self.padding = padding
        # layers
        self.conv = nn.Conv2d(in_nc, out_nc, 
                              kernel_size=kernel_size, 
                              stride=stride, 
                              padding=padding)
        self.bn = nn.BatchNorm2d(out_nc)
        
    def forward(self, batch, use_bn=False, use_relu=False, 
                use_maxpool=False, maxpool_kernelsize=None):
        batch = self.conv(batch)
        if use_bn:
            batch = self.bn(batch)
        if use_relu:
            batch = F.relu(batch)
        if use_maxpool:
            assert maxpool_kernelsize is not None
            batch = F.max_pool2d(batch, kernel_size=maxpool_kernelsize, stride=2)
        return batch

class blockRNN(nn.Module):
    def __init__(self, in_size, hidden_size, out_size, bidirectional, dropout=0):
        super(blockRNN, self).__init__()
        self.in_size = in_size
        self.hidden_size = hidden_size
        self.out_size = out_size
        self.bidirectional = bidirectional
        # layers
        self.gru = nn.GRU(in_size, hidden_size, bidirectional=bidirectional)
        
    def forward(self, batch, add_output=False):
        batch_size = batch.size(1)
        outputs, hidden = self.gru(batch)
        out_size = int(outputs.size(2) / 2)
        if add_output:
            outputs = outputs[:, :, :out_size] + outputs[:, :, out_size:]
        return outputs

# %% [markdown]
# ## <center>  Dataset

# %%
class CaptchaDataset(Dataset):
    def __init__(self, img_dir: str):
        pathes = os.listdir(img_dir)
        abspath = os.path.abspath(img_dir)
        self.img_dir = img_dir
        self.pathes = [os.path.join(abspath, path) for path in pathes]
        self.list_transforms = transforms.Compose([transforms.ToTensor()])
        
    def __len__(self):
        return len(self.pathes)
    
    def __getitem__(self, idx):
        path = self.pathes[idx]
        text = self.get_filename(path)
        img = Image.open(path).convert('RGB')
        img = self.transform(img)
        return img, text
    
    def get_filename(self, path: str) -> str:
        return os.path.basename(path).split('.')[0].lower().strip()
    
    def transform(self, img) -> torch.Tensor:
        return self.list_transforms(img)

# %% [markdown]
# ## <center> Dataset Params

# %%
TRAIN_DIR = Path('/kaggle/input/customocrdata/data/train')
VAL_DIR = Path('/kaggle/input/customocrdata/data/val')
BATCH_SIZE = 8
N_WORKERS = 4

# %%
alphabet = string.ascii_lowercase + string.digits
label_converter = strLabelConverter(alphabet)
alphabet
# Out:
# 'abcdefghijklmnopqrstuvwxyz0123456789'

# %%
train_dataset = CaptchaDataset(TRAIN_DIR)
val_dataset = CaptchaDataset(VAL_DIR)
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, 
                              num_workers=N_WORKERS, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, 
                            num_workers=N_WORKERS, shuffle=False)

# %%
imgs, texts = iter(val_dataloader).next()
print(imgs.shape, len(texts))
# Out:
# torch.Size([8, 3, 50, 200]) 8

# %% [markdown]
# ## <center> Model

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if type(m) in [nn.Linear, nn.Conv2d, nn.Conv1d]:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)
    elif classname.find('BatchNorm') != -1:
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_(0)

# %%
class CRNN(nn.Module):
    def __init__(self, hidden_size: int, 
                 vocab_size: int, 
                 bidirectional: bool = True, 
                 dropout: float = 0.5):
        super(CRNN, self).__init__()
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.bidirectional = bidirectional
        # make layers
        # convolutions 
        resnet = resnet18(pretrained=True)
        modules = list(resnet.children())[:-3]
        self.resnet = nn.Sequential(*modules)
        #PRETRAINED^
        
        
        
        self.cn6 = blockCNN(256, 256, kernel_size=3, padding=1)
        # RNN + Linear
        self.linear1 = nn.Linear(1024, 256)
        self.gru1 = blockRNN(256, hidden_size, hidden_size,
                             dropout=dropout, 
                             bidirectional=bidirectional)
        self.gru2 = blockRNN(hidden_size, hidden_size, vocab_size,
                             dropout=dropout,
                             bidirectional=bidirectional)
        self.linear2 = nn.Linear(hidden_size * 2, vocab_size)
        
    def forward(self, batch: torch.Tensor):
        batch_size = batch.size(0)
        # convolutions
        batch = self.resnet(batch)
        batch = self.cn6(batch, use_relu=True, use_bn=True)
        # make sequences of image features
        batch = batch.permute(0, 3, 1, 2)
        n_channels = batch.size(1)
        batch = batch.view(batch_size, n_channels, -1)
        batch = self.linear1(batch)
        # rnn layers
        batch = self.gru1(batch, add_output=True)
        batch = self.gru2(batch)
        # output
        batch = self.linear2(batch)
        batch = batch.permute(1, 0, 2)
        return batch

# %% [markdown]
# ## <center>  Model Parameters and Initialization

# %%
hidden_size = 256
vocab_size = len(alphabet) + 1 # extra character for blank symbol
bidirectional = True
dropout = 0.1
weight_decay = 1e-5
momentum = 0.9
clip_norm = 5
max_epoch = 50
print(vocab_size)
# Out:
# 37

# %%
crnn = CRNN(hidden_size=hidden_size, vocab_size=vocab_size, 
            bidirectional=bidirectional, dropout=dropout).to(device)
crnn(imgs.to(device)).shape
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# HBox(children=(FloatProgress(value=0.0, max=46827520.0), HTML(value='')))
# torch.Size([13, 8, 37])

# %%
lr = 0.02
optimizer = torch.optim.SGD(crnn.parameters(), lr=lr, nesterov=True, 
                            weight_decay=weight_decay, momentum=momentum)
critertion = nn.CTCLoss(blank=0)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, verbose=True, patience=5)

# %%
def validation(model, val_losses, label_converter):
    with torch.no_grad():
        model.eval()
        for batch_img, batch_text in val_dataloader:
            logits = crnn(batch_img.to(device))
            val_loss = calculate_loss(logits, batch_text, label_converter)
            val_losses.append(val_loss.item())
    return val_losses

# %%
def calculate_loss(logits, texts, label_converter):
    # get infomation from prediction
    device = logits.device
    input_len, batch_size, vocab_size = logits.size()
    # encode inputs
    logits = logits.log_softmax(2)
    encoded_texts, text_lens = label_converter.encode(texts)
    logits_lens = torch.full(size=(batch_size,), fill_value=input_len, dtype=torch.int32)
    # calculate ctc
    loss = critertion(logits, encoded_texts, 
                      logits_lens.to(device), text_lens)
    return loss

# %% [markdown]
# ## <center> Training

# %%
epoch = 0

# %%
train_losses = []
val_losses = []
val_epoch_len = len(val_dataset) // BATCH_SIZE
val_epoch_len
# Out:
# 26

# %%
try:
    while epoch <= max_epoch:
        crnn.train()
        for idx, (batch_imgs, batch_text) in enumerate(train_dataloader):
            optimizer.zero_grad()
            logits = crnn(batch_imgs.to(device))
            # calculate loss
            train_loss = calculate_loss(logits, batch_text, label_converter)
            if np.isnan(train_loss.detach().cpu().numpy()):
                continue
            train_losses.append(train_loss.item())
            # make backward
            train_loss.backward()

            nn.utils.clip_grad_norm_(crnn.parameters(), clip_norm)
            optimizer.step()

        val_losses = validation(crnn, val_losses, label_converter)
        
        # printing progress
        plot_loss(epoch, train_losses, val_losses)
        print_prediction(crnn, val_dataset, device, label_converter)
        
        scheduler.step(val_losses[-1])
        epoch += 1
except KeyboardInterrupt:
    pass

# %%
# saving model
torch.save(crnn.state_dict(), '/kaggle/working/crnn.pt')

# %% [markdown]
# #### <center> Calculating Accuracy and printing prediction

# %%
def acc_calc(model, dataset, label_converter) -> float:
    acc = 0
    with torch.no_grad():
        model.eval()
        for idx in range(len(dataset)):
            img, text = dataset[idx]
            logits = model(img.unsqueeze(0).to(device))
            pred_text = decode_prediction(logits.cpu(), label_converter)
            
            if pred_text == text:
                acc += 1
            
    return acc / len(dataset)

# %%
print_prediction(crnn, val_dataset, device, label_converter)

# %%
val_acc = acc_calc(crnn, val_dataset, label_converter)
train_acc = acc_calc(crnn, train_dataset, label_converter)
print('Validaton Accuracy: ', val_acc)
print('Training Accuracy: ', train_acc)
# Out:
# Validaton Accuracy:  0.8130841121495327
# Training Accuracy:  0.9450934579439252

# %%
crnn
# Out:
# CRNN(
#   (resnet): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (cn6): blockCNN(
#     (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (linear1): Linear(in_features=1024, out_features=256, bias=True)
#   (gru1): blockRNN(
#     (gru): GRU(256, 256, bidirectional=True)
#   )
#   (gru2): blockRNN(
#     (gru): GRU(256, 256, bidirectional=True)
#   )
#   (linear2): Linear(in_features=512, out_features=37, bias=True)
# )
